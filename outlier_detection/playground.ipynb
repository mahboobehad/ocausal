# %%
# In the name of Allah

import numpy as np 
import pandas as pd 

dp_count = 200
df = pd.DataFrame({'pct0' : np.random.randn(dp_count) * 100,
                   'pct1' : np.random.randn(dp_count) * 100,
                   'objects': np.random.randn(dp_count) * 100})

df
# Out:
#            pct0        pct1     objects
# 0     -7.180481  -39.968694   73.402451
# 1     -1.835310 -133.720208  -40.536085
# 2     -7.852297   17.224014   65.621409
# 3    156.843214  -37.995295 -158.968594
# 4    123.510470  -20.495570 -102.374260
# ..          ...         ...         ...
# 195  -57.498649   -4.304729  -34.903107
# 196   82.675780  -18.454739   27.912301
# 197   78.440660 -104.835843  114.227259
# 198  -61.291143  -72.917482   23.764093
# 199  -51.781999 -112.520072   33.229763
#
# [200 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

tf_cube = plt.figure().gca(projection='3d')
tf_cube.scatter(df['pct0'], df['pct1'], df['objects'])
tf_cube.set_xlabel('pct0')
tf_cube.set_ylabel('pct1')
tf_cube.set_zlabel('objects')
plt.show()

# %%
from numpy.linalg import inv
mu = np.array(df.mean())
cov_inv = inv(df.cov())
dp = np.array(df.iloc[1])
mahala_dist = np.sqrt((mu - dp).T @ cov_inv @ (mu - dp))
mahala_dist
# Out:
# 1.2053904086340839
